# %% [markdown]
# ### Requirements:
# - tensorflow
# - pandas
# - openpyxl
# - zipfile
# - scikit-learn
# - pillow
# - pyyaml
# - h5py
# - tensorflowjs

# %%
import zipfile
import os

def unzip(root_folder,force_unzip=False):
    if(os.path.exists(root_folder) and not force_unzip):
        print(f"Folder {root_folder} ready")
        return
    print("Unzip....", root_folder)
    zip_ref = zipfile.ZipFile(root_folder, 'r')
    zip_ref.extractall()
    zip_ref.close()
unzip('Iridology_dataset.zip')
unzip("Control.zip")
unzip("Diabetes.zip")
# Out:
# Running cells with '.conda (Python 3.9.19)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\sergio\Documents\testing\iris\.conda ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # Read Data

# %%
import os
import pandas as pd
import re

def create_image_dataframe(root_folder):
    data = []
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        if not os.path.isdir(folder_path):
            continue
        for image_name in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_name)
   
            if os.path.isfile(image_path) and  image_name.lower().endswith('.jpg'):
                data.append({ 'image_name':image_name,'path': image_path, "label": root_folder.lower(), "internal_id":folder_name})
    
    df = pd.DataFrame(data)
    return df

# %%
control = create_image_dataframe('Control')
control
# Out:
#                       image_name                                     path  \
# 0     IMG_2016_10_26_9999_20.JPG     Control\1\IMG_2016_10_26_9999_20.JPG
# 1    IMG_2016_10_26_9999_248.JPG   Control\10\IMG_2016_10_26_9999_248.JPG
# 2    IMG_2016_10_26_9999_257.JPG   Control\10\IMG_2016_10_26_9999_257.JPG
# 3    IMG_2016_06_11_9999_140.JPG  Control\100\IMG_2016_06_11_9999_140.JPG
# 4    IMG_2016_06_11_9999_148.JPG  Control\100\IMG_2016_06_11_9999_148.JPG
# ..                           ...                                      ...
# 170  IMG_2016_10_24_9999_263.JPG   Control\97\IMG_2016_10_24_9999_263.JPG
# 171  IMG_2016_10_24_9999_268.JPG   Control\97\IMG_2016_10_24_9999_268.JPG
# 172  IMG_2016_06_11_9999_274.JPG   Control\98\IMG_2016_06_11_9999_274.JPG
# 173  IMG_2016_06_11_9999_280.JPG   Control\98\IMG_2016_06_11_9999_280.JPG
# 174  IMG_2016_06_11_9999_269.JPG   Control\99\IMG_2016_06_11_9999_269.JPG
#
#        label internal_id
# 0    control           1
# 1    control          10
# 2    control          10
# 3    control         100
# 4    control         100
# ..       ...         ...
# 170  control          97
# 171  control          97
# 172  control          98
# 173  control          98
# 174  control          99
#
# [175 rows x 4 columns]

# %%
diabetes = create_image_dataframe('Diabetes')
diabetes
# Out:
#                       image_name                                     path  \
# 0    IMG_2016_11_02_9999_334.JPG   Diabetes\1\IMG_2016_11_02_9999_334.JPG
# 1    IMG_2016_11_02_9999_335.JPG   Diabetes\1\IMG_2016_11_02_9999_335.JPG
# 2    IMG_2016_06_25_9999_226.JPG  Diabetes\10\IMG_2016_06_25_9999_226.JPG
# 3     IMG_2016_06_01_9999_21.JPG  Diabetes\100\IMG_2016_06_01_9999_21.JPG
# 4     IMG_2016_06_01_9999_35.JPG  Diabetes\101\IMG_2016_06_01_9999_35.JPG
# ..                           ...                                      ...
# 145  IMG_2016_06_11_9999_116.JPG  Diabetes\96\IMG_2016_06_11_9999_116.JPG
# 146  IMG_2016_06_11_9999_120.JPG  Diabetes\96\IMG_2016_06_11_9999_120.JPG
# 147  IMG_2016_06_08_9999_389.JPG  Diabetes\97\IMG_2016_06_08_9999_389.JPG
# 148   IMG_2016_06_01_9999_28.JPG   Diabetes\98\IMG_2016_06_01_9999_28.JPG
# 149    IMG_2016_06_01_9999_6.JPG    Diabetes\99\IMG_2016_06_01_9999_6.JPG
#
#         label internal_id
# 0    diabetes           1
# 1    diabetes           1
# 2    diabetes          10
# 3    diabetes         100
# 4    diabetes         101
# ..        ...         ...
# 145  diabetes          96
# 146  diabetes          96
# 147  diabetes          97
# 148  diabetes          98
# 149  diabetes          99
#
# [150 rows x 4 columns]

# %% [markdown]
# #### Combine data

# %%
merged_df = pd.concat([diabetes, control])
merged_df
# Out:
#                       image_name                                     path  \
# 0    IMG_2016_11_02_9999_334.JPG   Diabetes\1\IMG_2016_11_02_9999_334.JPG
# 1    IMG_2016_11_02_9999_335.JPG   Diabetes\1\IMG_2016_11_02_9999_335.JPG
# 2    IMG_2016_06_25_9999_226.JPG  Diabetes\10\IMG_2016_06_25_9999_226.JPG
# 3     IMG_2016_06_01_9999_21.JPG  Diabetes\100\IMG_2016_06_01_9999_21.JPG
# 4     IMG_2016_06_01_9999_35.JPG  Diabetes\101\IMG_2016_06_01_9999_35.JPG
# ..                           ...                                      ...
# 170  IMG_2016_10_24_9999_263.JPG   Control\97\IMG_2016_10_24_9999_263.JPG
# 171  IMG_2016_10_24_9999_268.JPG   Control\97\IMG_2016_10_24_9999_268.JPG
# 172  IMG_2016_06_11_9999_274.JPG   Control\98\IMG_2016_06_11_9999_274.JPG
# 173  IMG_2016_06_11_9999_280.JPG   Control\98\IMG_2016_06_11_9999_280.JPG
# 174  IMG_2016_06_11_9999_269.JPG   Control\99\IMG_2016_06_11_9999_269.JPG
#
#         label internal_id
# 0    diabetes           1
# 1    diabetes           1
# 2    diabetes          10
# 3    diabetes         100
# 4    diabetes         101
# ..        ...         ...
# 170   control          97
# 171   control          97
# 172   control          98
# 173   control          98
# 174   control          99
#
# [325 rows x 4 columns]

# %%
shuffled_df = merged_df.sample(frac=1).reset_index(drop=True)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(shuffled_df, test_size=0.3)

# %%
df_train
# Out:
#                       image_name                                     path  \
# 10   IMG_2016_06_06_9999_184.JPG  Diabetes\61\IMG_2016_06_06_9999_184.JPG
# 108  IMG_2016_09_05_9999_142.JPG  Control\118\IMG_2016_09_05_9999_142.JPG
# 241  IMG_2016_08_29_9999_349.JPG   Control\96\IMG_2016_08_29_9999_349.JPG
# 211  IMG_2016_06_06_9999_165.JPG  Diabetes\58\IMG_2016_06_06_9999_165.JPG
# 164  IMG_2016_05_23_9999_335.JPG  Diabetes\46\IMG_2016_05_23_9999_335.JPG
# ..                           ...                                      ...
# 49   IMG_2016_06_18_9999_199.JPG  Diabetes\87\IMG_2016_06_18_9999_199.JPG
# 58   IMG_2016_06_11_9999_187.JPG  Diabetes\92\IMG_2016_06_11_9999_187.JPG
# 94   IMG_2016_08_22_9999_291.JPG   Control\64\IMG_2016_08_22_9999_291.JPG
# 156  IMG_2016_05_23_9999_268.JPG  Diabetes\44\IMG_2016_05_23_9999_268.JPG
# 244  IMG_2016_06_18_9999_192.JPG   Diabetes\2\IMG_2016_06_18_9999_192.JPG
#
#         label internal_id
# 10   diabetes          61
# 108   control         118
# 241   control          96
# 211  diabetes          58
# 164  diabetes          46
# ..        ...         ...
# 49   diabetes          87
# 58   diabetes          92
# 94    control          64
# 156  diabetes          44
# 244  diabetes           2
#
# [227 rows x 4 columns]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_dataframe(
  df_train,
  target_size=(300, 300),
  x_col='path',
  y_col='label',
  class_mode='binary'
)
# Out:
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Found 227 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1/255)

validation_generator = train_datagen.flow_from_dataframe(
  df_test,
  target_size=(300, 300),
  x_col='path',
  y_col='label',
  class_mode='binary'
)
# Out:
# Found 98 validated image filenames belonging to 2 classes.

# %% [markdown]
# # TRAIN

# %%
model = tf.keras.models.Sequential([
   tf.keras.layers.Input(shape=(300,300, 3)),
  tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPool2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 149, 149, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1704097 (6.50 MB)
# Trainable params: 1704097 (6.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
       optimizer='adam',
       metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(
  train_generator,
  epochs=15,
  validation_data=validation_generator
)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 15s 2s/step - loss: 0.7120 - accuracy: 0.4934 - val_loss: 0.6986 - val_accuracy: 0.4082
# Epoch 2/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.7089 - accuracy: 0.4846 - val_loss: 0.6809 - val_accuracy: 0.5918
# Epoch 3/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6912 - accuracy: 0.5463 - val_loss: 0.6866 - val_accuracy: 0.6224
# Epoch 4/15
# 8/8 [==============================] - 12s 2s/step - loss: 0.6921 - accuracy: 0.6432 - val_loss: 0.6464 - val_accuracy: 0.5918
# Epoch 5/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6652 - accuracy: 0.5771 - val_loss: 0.6179 - val_accuracy: 0.7347
# Epoch 6/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6680 - accuracy: 0.5903 - val_loss: 0.5935 - val_accuracy: 0.7245
# Epoch 7/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6036 - accuracy: 0.7093 - val_loss: 0.4950 - val_accuracy: 0.8265
# Epoch 8/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6134 - accuracy: 0.6828 - val_loss: 0.5206 - val_accuracy: 0.8163
# Epoch 9/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.5520 - accuracy: 0.7313 - val_loss: 0.5196 - val_accuracy: 0.7551
# Epoch 10/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.5351 - accuracy: 0.7445 - val_loss: 0.4856 - val_accuracy: 0.7857
# Epoch 11/15
# 8/8 [==============================] - 12s 2s/step - loss: 0.5098 - accuracy: 0.8150 - val_loss: 0.5302 - val_accuracy: 0.7347
# Epoch 12/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.4524 - accuracy: 0.8150 - val_loss: 0.5198 - val_accuracy: 0.7551
# Epoch 13/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.5217 - accuracy: 0.7137 - val_loss: 0.7519 - val_accuracy: 0.4286
# Epoch 14/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6680 - accuracy: 0.5727 - val_loss: 0.6776 - val_accuracy: 0.6939
# Epoch 15/15
# 8/8 [==============================] - 12s 2s/step - loss: 0.6795 - accuracy: 0.5903 - val_loss: 0.6664 - val_accuracy: 0.7551

# %%
model.save('classifier-diabete.keras')

# %%
# %pip install tensorflowjs -v

# %%
import os

import tensorflow as tf
from tensorflow import keras
load_model = tf.keras.models.load_model('classifier-diabete.h5')
load_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 149, 149, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1704097 (6.50 MB)
# Trainable params: 1704097 (6.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflowjs as tfjs 
output_dir = 'tfjs_model'

tfjs.converters.save_keras_model(load_model, output_dir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import tensorflowjs as tfjs
#       2 output_dir = 'tfjs_model'
#       4 tfjs.converters.save_keras_model(load_model, output_dir)
#
# File c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\tensorflowjs\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# File c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\tensorflowjs\converters\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports,line-too-long
# ---> 21 from tensorflowjs.converters.converter import convert
#      22 from tensorflowjs.converters.keras_h5_conversion import save_keras_model
#      23 from tensorflowjs.converters.keras_tfjs_loader import deserialize_keras_model
#
# File c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\tensorflowjs\converters\converter.py:38
#      36 from tensorflowjs.converters import keras_h5_conversion as conversion
#      37 from tensorflowjs.converters import keras_tfjs_loader
# ---> 38 from tensorflowjs.converters import tf_saved_model_conversion_v2
#      39 from zipfile import ZipFile, is_zipfile
#      42 def dispatch_keras_h5_to_tfjs_layers_model_conversion(
#      43     h5_path, output_dir=None, quantization_dtype_map=None,
#      44     split_weights_by_layer=False,
#      45     weight_shard_size_bytes=1024 * 1024 * 4,
#      46     metadata=None):
#
# File c:\Users\sergio\Documents\testing\iris\.conda\lib\site-packages\tensorflowjs\converters\tf_saved_model_conversion_v2.py:28
#      25 from zipfile import ZipFile
#      27 # Required to load saved models that use TFDF.
# ---> 28 import tensorflow_decision_forests
#      29 import tensorflow as tf
#      30 from tensorflow.core.framework import function_pb2
#
# ModuleNotFoundError: No module named 'tensorflow_decision_forests'

# %%
# %pip freeze
# Out:
# absl-py==2.1.0
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1698341106958/work
# astunparse==1.6.3
# cachetools==5.5.0
# certifi==2024.8.30
# charset-normalizer==3.3.2
# chex==0.1.86
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1666700638685/work
# comm @ file:///home/conda/feedstock_root/build_artifacts/comm_1710320294760/work
# debugpy @ file:///D:/bld/debugpy_1727240768006/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# et-xmlfile==1.1.0
# etils==1.5.2
# exceptiongroup @ file:///home/conda/feedstock_root/build_artifacts/exceptiongroup_1720869315914/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1725214404607/work
# flatbuffers==24.3.25
# flax==0.8.5
# fsspec==2024.9.0
# gast==0.6.0
# google-auth==2.35.0
# google-auth-oauthlib==1.2.1
# google-pasta==0.2.0
# grpcio==1.66.2
# h5py==3.12.1
# humanize==4.10.0
# idna==3.10
# importlib_metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1726082825846/work
# importlib_resources==6.4.5
# ipykernel @ file:///D:/bld/ipykernel_1719845595208/work
# ipython @ file:///D:/bld/ipython_1701831845989/work
# jax==0.4.30
# jaxlib==0.4.30
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1696326070614/work
# joblib==1.4.2
# jupyter_client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1726610684920/work
# jupyter_core @ file:///D:/bld/jupyter_core_1710257377578/work
# keras==2.15.0
# libclang==18.1.1
# Markdown==3.7
# markdown-it-py==3.0.0
# MarkupSafe==2.1.5
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1713250518406/work
# mdurl==0.1.2
# ml-dtypes==0.3.2
# msgpack==1.1.0
# nest_asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1705850609492/work
# numpy==1.26.4
# oauthlib==3.2.2Note: you may need to restart the kernel to use updated packages.
#
# openpyxl==3.1.5
# opt_einsum==3.4.0
# optax==0.2.3
# orbax-checkpoint==0.6.4
# packaging==23.2
# pandas==2.2.3
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1712320355065/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# pillow==10.4.0
# platformdirs @ file:///home/conda/feedstock_root/build_artifacts/platformdirs_1726613481435/work
# prompt_toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1727341649933/work
# protobuf==4.25.5
# psutil @ file:///D:/bld/psutil_1725738022539/work
# pure_eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1721585709575/work
# pyasn1==0.6.1
# pyasn1_modules==0.4.1
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1714846767233/work
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1709299778482/work
# pytz==2024.2
# pywin32==306
# PyYAML==6.0.2
# pyzmq @ file:///D:/bld/pyzmq_1725449105237/work
# requests==2.32.3
# requests-oauthlib==2.0.0
# rich==13.8.1
# rsa==4.9
# scikit-learn==1.5.2
# scipy==1.13.1
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1669632077133/work
# tensorboard==2.15.2
# tensorboard-data-server==0.7.2
# tensorflow==2.15.1
# tensorflow-estimator==2.15.0
# tensorflow-hub==0.16.1
# tensorflow-intel==2.15.1
# tensorflow-io-gcs-filesystem==0.31.0
# tensorflow_decision_forests==1.8.1
# tensorflowjs==4.21.0
# tensorstore==0.1.66
# termcolor==2.4.0
# tf_keras==2.15.1
# threadpoolctl==3.5.0
# toolz==0.12.1
# tornado @ file:///D:/bld/tornado_1724956258948/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1713535121073/work
# typing_extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1717802530399/work
# tzdata==2024.2
# urllib3==2.2.3
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1704731205417/work
# Werkzeug==3.0.4
# wrapt==1.14.1
# wurlitzer==3.1.1
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1726248574750/work

# %%
# !pip3 install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (4.21.0)
# Requirement already satisfied: flax>=0.7.2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (0.8.5)
# Requirement already satisfied: importlib_resources>=5.9.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (6.4.5)
# Requirement already satisfied: jax>=0.4.13 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (0.4.30)
# Requirement already satisfied: jaxlib>=0.4.13 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (0.4.30)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (2.15.1)
# Requirement already satisfied: tf-keras>=2.13.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (2.15.1)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (1.8.1)
# Requirement already satisfied: six<2,>=1.16.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.2.3)
# Requirement already satisfied: orbax-checkpoint in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: tensorstore in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.66)
# Requirement already satisfied: rich>=11.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (13.8.1)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.20.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from jax>=0.4.13->tensorflowjs) (0.3.2)
# Requirement already satisfied: opt-einsum in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from jax>=0.4.13->tensorflowjs) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from jax>=0.4.13->tensorflowjs) (8.5.0)
# Requirement already satisfied: tensorflow-intel==2.15.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.66.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.0)
# Requirement already satisfied: pandas in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.44.0)
# Requirement already satisfied: wurlitzer in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.18.0)
# Requirement already satisfied: chex>=0.1.86 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.86)
# Requirement already satisfied: etils[epy] in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (1.5.2)
# Requirement already satisfied: nest_asyncio in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from chex>=0.1.86->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: fsspec in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2024.9.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.2.2)

# %%
# %pip --version

# %%
# %pip uninstall tensorflow tensorflow-decision-forests
# %pip install tensorflow tensorflow-decision-forests
# Out:
# Requirement already satisfied: tensorflow in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (2.15.1)
# Requirement already satisfied: tensorflow-decision-forests in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (1.8.1)
# Requirement already satisfied: tensorflow-intel==2.15.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.0)
# Requirement already satisfied: pandas in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests) (2.2.3)
# Requirement already satisfied: wheel in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests) (0.44.0)
# Requirement already satisfied: wurlitzer in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorflow-decision-forests) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pandas->tensorflow-decision-forests) (2024.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sergio\documents\testing\iris\.conda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
